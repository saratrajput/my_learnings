# %%
Threads.nthreads()
# Out:
# Base.Threads

# %%
# Example from Julia documentation
mysum = Ref(0);

Threads.@threads for i in 1:1000
    mysum[] += 1
end

# %%
mysum[]
# Out:
# 1000

# %%
mysum = Threads.Atomic{Int64}(0)
# Out:
# Base.Threads.Atomic{Int64}(0)

# %%
Threads.@threads for i ∈ 1:1000
    Threads.atomic_add!(mysum, 1)
end

# %%
mysum[]
# Out:
# 1000

# %%
using Base.Threads

# %%
using BenchmarkTools

# %%
v = [rand(1_000_000) for i ∈ 1:36]
# Out:
# 36-element Vector{Vector{Float64}}:
#  [0.9157983942796802, 0.038979968727382075, 0.5590676682883007, 0.8471327266935237, 0.8310397353569929, 0.08117774349363227, 0.3923431137617194, 0.11168785395260938, 0.5278095279670166, 0.029217011769528844  …  0.4000006613142364, 0.4145154369924974, 0.021141167895470825, 0.0886355315059627, 0.8325029146679261, 0.7580048019015817, 0.6842581617920354, 0.09138234652004695, 0.5665593271827212, 0.22425934697201133]
#  [0.19508372103888494, 0.7669545048530217, 0.38322570874437345, 0.7989449973733254, 0.24392817649785803, 0.0043627785831729105, 0.16404547308244632, 0.5210024438132611, 0.4299657813073873, 0.06644708142644218  …  0.12738572149887828, 0.4621877552452044, 0.7484715330862629, 0.4981129171387132, 0.9713822158877582, 0.32543270020937975, 0.9853838356386516, 0.8711100412029705, 0.6338378465631808, 0.8252198897510533]
#  [0.6407883925890097, 0.7484904171346016, 0.7072196829602481, 0.05045190627717189, 0.27573699263479823, 0.4375669158422393, 0.8921063511751559, 0.5115083387034205, 0.8989798454915634, 0.6266242224968377  …  0.36453818628362544, 0.2524070813071596, 0.05554535335216193, 0.5932308106950704, 0.8868044463925556, 0.4723778589691269, 0.7100370834136472, 0.761213785755196, 0.7979636379634526, 0.23661570398582743]
#  [0.48951746771529725, 0.2914807110298919, 0.38469827055684447, 0.010122889373440747, 0.3080764732892568, 0.6224124994528055, 0.5626754201350039, 0.4107040050863269, 0.6391753743017435, 0.9857370137171191  …  0.7387691507545228, 0.2630002357404284, 0.5844940746876854, 0.16418611874857036, 0.3283916379736104, 0.7159994125861854, 0.3113347449397572, 0.6073356655909941, 0.3508136003416976, 0.9737086716913462]
#  [0.33808900913287, 0.7590646526952307, 0.3611037274121992, 0.5366855588420786, 0.6269508988466405, 0.26265990012589513, 0.06845739422322195, 0.4290005178372197, 0.8461629846841803, 0.8147908698372529  …  0.23540613835626845, 0.7020431403411255, 0.9194368844441259, 0.4454338236504882, 0.6614644951786914, 0.9837336001348457, 0.550999135281169, 0.5883380823064543, 0.5598218027988076, 0.8137421335710723]
# vecmean (generic function with 1 method)

# %%
vecmean(v[1])
# Out:
# 0.49986632132561204

# %%
function serial_mean(vect)
    sums = zeros(length(vect))
    for i in eachindex(vect)
        sums[i] = vecmean(vect[i])
    end
    return sums
end
# Out:
# serial_mean (generic function with 1 method)

# %%
@btime serial_mean(v)
# Out:
#   68.809 ms (1 allocation: 368 bytes)
# 36-element Vector{Float64}:
#  0.49986632132561204
#  0.500028128988724
#  0.4998143253191473
#  0.49990151304276814
#  0.49943094850126685
#  0.4999243186084687
#  0.5002437406932655
#  0.5003378037796661
#  0.5002384583986953
#  0.5001400892644134
#  ⋮
#  0.4997573157860112
#  0.4995731868676817
#  0.499958919993611
#  0.4998479811575723
#  0.49980814778324734
#  0.49954773305203753
#  0.4999873277918828
#  0.500130863460412
#  0.49940937225623805

# %%
function threaded_mean(vect)
    sums = zeros(length(vect))
    Threads.@threads for i in eachindex(vect)
        sums[i] = vecmean(vect[i])
    end
    return sums
end
# Out:
# threaded_mean (generic function with 1 method)

# %%
@btime threaded_mean(v)
# Out:
#   66.840 ms (7 allocations: 928 bytes)
# 36-element Vector{Float64}:
#  0.49986632132561204
#  0.500028128988724
#  0.4998143253191473
#  0.49990151304276814
#  0.49943094850126685
#  0.4999243186084687
#  0.5002437406932655
#  0.5003378037796661
#  0.5002384583986953
#  0.5001400892644134
#  ⋮
#  0.4997573157860112
#  0.4995731868676817
#  0.499958919993611
#  0.4998479811575723
#  0.49980814778324734
#  0.49954773305203753
#  0.4999873277918828
#  0.500130863460412
#  0.49940937225623805

# %%
function spawn_mean(vect)
    tasks = [Threads.@spawn vecmean(vect[i]) for i in 1:length(vect)]
    sums = [fetch(t) for t in tasks]
    return sums
end
# Out:
# spawn_mean (generic function with 1 method)

# %%
@btime spawn_mean(v)
# Out:
#   68.987 ms (220 allocations: 18.16 KiB)
# 36-element Vector{Float64}:
#  0.49986632132561204
#  0.500028128988724
#  0.4998143253191473
#  0.49990151304276814
#  0.49943094850126685
#  0.4999243186084687
#  0.5002437406932655
#  0.5003378037796661
#  0.5002384583986953
#  0.5001400892644134
#  ⋮
#  0.4997573157860112
#  0.4995731868676817
#  0.499958919993611
#  0.4998479811575723
#  0.49980814778324734
#  0.49954773305203753
#  0.4999873277918828
#  0.500130863460412
#  0.49940937225623805

# %%
v1 = rand(20_000);
v2 = [rand(1000) for i in 1:143];
v = [v1, v2...];

# %%
sum_serial = serial_mean(v);
sum_thread = threaded_mean(v);
sum_spawn = spawn_mean(v);

# %%
sum_serial == sum_thread == sum_spawn
# Out:
# true

# %%
@btime serial_mean(v);
@btime threaded_mean(v);
@btime spawn_mean(v);
# Out:
#   277.512 μs (1 allocation: 1.22 KiB)
#   279.228 μs (7 allocations: 1.77 KiB)
#   322.162 μs (868 allocations: 72.22 KiB)
